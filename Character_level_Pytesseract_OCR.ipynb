# %% [markdown]
# <a href="https://colab.research.google.com/github/Solyemin/OCR_Divyanshu_Vishal/blob/main/Character_level_Pytesseract_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install numpy
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# !pip install matplotlib

# %%
# !apt install tesseract-ocr
# !apt install libtesseract-dev

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np
import pandas as pd
import shutil
import os
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
im_path="/content/drive/My Drive/t2.jpg"
img=cv2.imread(im_path)

# %%
extractedInformation = pytesseract.image_to_string(img)
#print(type(extractedInformation))
print(extractedInformation)

# %%
list1=[]
for i in range (5,256):
    list1.append(i)
#print(list1)

# %%
hImg,wImg,__=img.shape
boxes=pytesseract.image_to_boxes(img)
print(boxes)
ch = input("Enter the char : ")
for b in boxes.splitlines():
    j=random.choice(list1)
    k=random.choice(list1)
    l=random.choice(list1)
    #print(b)
    b=b.split(' ')
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    
    if(b[0]==ch[0]):
      cv2.rectangle(img,(x,hImg-y),(w,hImg-h),(j,k,l),2)
      cv2.putText(img,b[0],(x,hImg-y+25),cv2.FONT_HERSHEY_COMPLEX,1,(j,k,l),2)
      

cv2_imshow(img)
# Out:
# | 100 557 102 568 0
# u 128 557 138 567 0
# s 141 555 147 567 0
# e 148 557 156 567 0
# d 159 557 170 572 0
# 4 192 559 207 572 0
# o 192 559 211 572 0
# d 232 560 246 573 0
# o 247 560 256 568 0
# m 270 562 285 573 0
# e 286 562 301 572 0
# s 316 563 323 573 0
# a 325 562 333 571 0
# m 335 563 350 574 0
# e 352 564 361 574 0
# n 379 564 394 577 0
# i 385 549 397 583 0
# n 395 564 408 579 0
# g 409 553 420 574 0
# a 434 566 443 574 0
# s 444 565 451 577 0
# y 467 559 477 577 0
# o 479 568 487 577 0
# u 488 568 499 579 0
# w 514 569 527 582 0
# i 514 569 532 578 0
# t 534 569 541 582 0
# h 542 569 554 581 0
# t 570 568 589 581 0
# e 589 568 597 579 0
# p 602 557 619 589 0
# e 612 561 620 577 0
# n 621 569 627 578 0
# c 629 569 637 578 0
# i 639 568 648 579 0
# l 649 568 658 584 0
# t 676 572 679 584 0
# i 681 573 684 580 0
# n 686 572 690 582 0
# e 690 571 706 583 0
# s 708 573 714 584 0
# a 734 573 745 582 0
# n 736 573 754 587 0
# d 745 574 765 587 0
# e 783 576 791 585 0
# ...
